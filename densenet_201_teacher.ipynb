# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import timm


from paddy_10_data_loader import load_train_val_data
from helper_utils import training_loop

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
train_loader, val_loader = load_train_val_data(batch_size=64)

# %% [markdown]
# ## Teacher - DenseNet201

# %%
epochs = 30

# %%
dense201 = timm.create_model(
    "densenet201.tv_in1k",
    pretrained=False,
    num_classes=10,
    )

loss_function = nn.CrossEntropyLoss()
optimizer = optim.Adam(dense201.parameters(), lr=0.001) 
lr_scheduler = optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=epochs, eta_min=0.00001)

# %%
trained_dense201, history = training_loop(
        model=dense201,
        train_loader=train_loader,
        val_loader=val_loader,
        loss_function=loss_function,
        optimizer=optimizer,
        num_epochs=epochs,
        device=device,
        scheduler=lr_scheduler,
        save_path="densenet201_teacher.pth",
)
# Out:
# Overall Progress:   0%|          | 0/4920 [00:00<?, ?it/s]
# Epoch 1/30 - Train Acc: 45.0679%, Train Loss: 1.5908, Val Loss: 1.6750, Val Acc: 45.2975%
# Epoch 2/30 - Train Acc: 58.9451%, Train Loss: 1.2028, Val Loss: 2.0949, Val Acc: 44.4818%
# Epoch 3/30 - Train Acc: 67.3675%, Train Loss: 0.9783, Val Loss: 1.1626, Val Acc: 62.3800%
# Epoch 4/30 - Train Acc: 75.0931%, Train Loss: 0.7428, Val Loss: 2.2823, Val Acc: 49.8560%
# Epoch 5/30 - Train Acc: 79.8750%, Train Loss: 0.6095, Val Loss: 1.0297, Val Acc: 68.2822%
# Epoch 6/30 - Train Acc: 81.0525%, Train Loss: 0.5672, Val Loss: 0.9571, Val Acc: 69.2898%
# Epoch 7/30 - Train Acc: 83.7919%, Train Loss: 0.5000, Val Loss: 0.6420, Val Acc: 79.8464%
# Epoch 8/30 - Train Acc: 86.0747%, Train Loss: 0.4256, Val Loss: 0.7442, Val Acc: 77.8791%
# Epoch 9/30 - Train Acc: 87.5165%, Train Loss: 0.3927, Val Loss: 0.5457, Val Acc: 84.2131%
# Epoch 10/30 - Train Acc: 89.7994%, Train Loss: 0.3158, Val Loss: 0.5702, Val Acc: 83.6372%
# Epoch 11/30 - Train Acc: 92.8031%, Train Loss: 0.2194, Val Loss: 1.1930, Val Acc: 71.6891%
# Epoch 12/30 - Train Acc: 92.4546%, Train Loss: 0.2416, Val Loss: 0.3954, Val Acc: 87.8599%
# Epoch 13/30 - Train Acc: 94.6534%, Train Loss: 0.1716, Val Loss: 0.4330, Val Acc: 88.4357%
# Epoch 14/30 - Train Acc: 95.5425%, Train Loss: 0.1362, Val Loss: 0.5629, Val Acc: 85.3167%
# Epoch 15/30 - Train Acc: 92.9953%, Train Loss: 0.2323, Val Loss: 0.4148, Val Acc: 89.0115%
# Epoch 16/30 - Train Acc: 95.7587%, Train Loss: 0.1321, Val Loss: 0.3466, Val Acc: 90.0192%
# Epoch 17/30 - Train Acc: 96.3715%, Train Loss: 0.1227, Val Loss: 0.5985, Val Acc: 82.2937%
# Epoch 18/30 - Train Acc: 95.5305%, Train Loss: 0.1447, Val Loss: 0.2372, Val Acc: 93.8100%
# Epoch 19/30 - Train Acc: 98.5822%, Train Loss: 0.0478, Val Loss: 0.2120, Val Acc: 94.3378%
# Epoch 20/30 - Train Acc: 98.5943%, Train Loss: 0.0461, Val Loss: 0.2513, Val Acc: 93.8100%
# Epoch 21/30 - Train Acc: 98.6904%, Train Loss: 0.0437, Val Loss: 0.2148, Val Acc: 94.5777%
# Epoch 22/30 - Train Acc: 99.4593%, Train Loss: 0.0185, Val Loss: 0.2696, Val Acc: 93.1862%
# Epoch 23/30 - Train Acc: 98.5943%, Train Loss: 0.0496, Val Loss: 0.2181, Val Acc: 94.5777%
# Epoch 24/30 - Train Acc: 99.5434%, Train Loss: 0.0216, Val Loss: 0.2181, Val Acc: 94.6257%
# Epoch 25/30 - Train Acc: 99.7957%, Train Loss: 0.0122, Val Loss: 0.2234, Val Acc: 95.0096%
# Epoch 26/30 - Train Acc: 99.8198%, Train Loss: 0.0103, Val Loss: 0.2167, Val Acc: 94.7697%
# Epoch 27/30 - Train Acc: 99.7837%, Train Loss: 0.0107, Val Loss: 0.2129, Val Acc: 95.0576%
# Epoch 28/30 - Train Acc: 99.9159%, Train Loss: 0.0086, Val Loss: 0.2193, Val Acc: 95.0576%
# Epoch 29/30 - Train Acc: 99.8558%, Train Loss: 0.0113, Val Loss: 0.2215, Val Acc: 95.1536%
# Epoch 30/30 - Train Acc: 99.8078%, Train Loss: 0.0098, Val Loss: 0.2184, Val Acc: 94.9616%
#   -> Model saved to 'densenet201_teacher.pth'
